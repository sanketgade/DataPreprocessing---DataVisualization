# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Gadewar'

# %%
os.chdir("F:\COGNITIOR")

# %%
dt= pd.read_excel("F:\\COGNITIOR\\dataframe\\Employee_Data.xls")

# %%
dt
# Out:
#     Employee Id First Name   Last Name           Department   Age  Experience  \
# 0             1        Joy        Bass  Sales and Marketing  28.0         3.0
# 1             2     Sheila       Garza  Sales and Marketing  22.0         1.0
# 2             3       John      Bryant   Customer Relations  22.0         1.0
# 3             4  Christian      Farley   Customer Relations  22.0         1.0
# 4             5   Colorado       Bowen           Accounting  27.0         0.0
# 5             6     Elijah    Matthews           Accounting  26.0         5.0
# 6             7         Bo      Mcleod   Customer Relations  24.0         6.0
# 7             8       Zena    Melendez   Customer Relations  29.0         2.0
# 8             9     Tucker     Michael  Sales and Marketing  29.0         5.0
# 9            10      Lucas        Rowe   Customer Relations  30.0         6.0
# 10           11    Mallory      Walker           Accounting  26.0         5.0
# ...

# %%
dt.isnull().sum()
# Out:
# Employee Id     0
# First Name      0
# Last Name       0
# Department     19
# Age            18
# Experience     10
# Salary          0
# dtype: int64

# %%
import seaborn as sns
sns.boxplot(y='Age',data=dt)

# %%
x= dt.iloc[:,3:6].values

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, nan],
#        ['Customer Relations', 22.0, nan],
#        ['Accounting', 25.0, nan],
#        ['Accounting', 27.0, nan],
#        [nan, 25.0, nan],
#        [nan, 22.0, nan],
#        [nan, 22.0, nan],
#        [nan, 24.0, nan],
#        [nan, 27.0, nan],
#        [nan, 22.0, nan],
#        [nan, 33.0, 13.0],
#        [nan, 36.0, 7.0],
# ...

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x= dt.iloc[:,3:6].values

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, nan],
#        ['Customer Relations', 22.0, nan],
#        ['Accounting', 25.0, nan],
#        ['Accounting', 27.0, nan],
#        [nan, 25.0, nan],
#        [nan, 22.0, nan],
#        [nan, 22.0, nan],
#        [nan, 24.0, nan],
#        [nan, 27.0, nan],
#        [nan, 22.0, nan],
#        [nan, 33.0, 13.0],
#        [nan, 36.0, 7.0],
# ...

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values=  'NaN',strategy ='mean',axis=0)
imputer= imputer.fit(x[:,1:3])
x[:,1:3]=imputer.transform(x[:,1:3])
# Out:
# C:\Users\Gadewar\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, nan],
#        ['Customer Relations', 22.0, nan],
#        ['Accounting', 25.0, nan],
#        ['Accounting', 27.0, nan],
#        [nan, 25.0, nan],
#        [nan, 22.0, nan],
#        [nan, 22.0, nan],
#        [nan, 24.0, nan],
#        [nan, 27.0, nan],
#        [nan, 22.0, nan],
#        [nan, 33.0, 13.0],
#        [nan, 36.0, 7.0],
# ...

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, nan],
#        ['Customer Relations', 22.0, nan],
#        ['Accounting', 25.0, nan],
#        ['Accounting', 27.0, nan],
#        [nan, 25.0, nan],
#        [nan, 22.0, nan],
#        [nan, 22.0, nan],
#        [nan, 24.0, nan],
#        [nan, 27.0, nan],
#        [nan, 22.0, nan],
#        [nan, 33.0, 13.0],
#        [nan, 36.0, 7.0],
# ...

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values=  'NaN',strategy ='median',axis=0)
imputer= imputer.fit(x[:,1:3])
x[:,1:3]=imputer.transform(x[:,1:3])
# Out:
# C:\Users\Gadewar\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, 14.766666666666667],
#        ['Customer Relations', 22.0, 14.766666666666667],
#        ['Accounting', 25.0, 14.766666666666667],
#        ['Accounting', 27.0, 14.766666666666667],
#        [nan, 25.0, 14.766666666666667],
#        [nan, 22.0, 14.766666666666667],
#        [nan, 22.0, 14.766666666666667],
# ...

# %%
y= dt.iloc[:,3:6].values

# %%
y
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, nan],
#        ['Customer Relations', 22.0, nan],
#        ['Accounting', 25.0, nan],
#        ['Accounting', 27.0, nan],
#        [nan, 25.0, nan],
#        [nan, 22.0, nan],
#        [nan, 22.0, nan],
#        [nan, 24.0, nan],
#        [nan, 27.0, nan],
#        [nan, 22.0, nan],
#        [nan, 33.0, 13.0],
#        [nan, 36.0, 7.0],
# ...

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values=  'NaN',strategy ='median',axis=0)
imputer= imputer.fit(y[:,1:3])
y[:,1:3]=imputer.transform(x[:,1:3])
# Out:
# C:\Users\Gadewar\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
y
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, 14.766666666666667],
#        ['Customer Relations', 22.0, 14.766666666666667],
#        ['Accounting', 25.0, 14.766666666666667],
#        ['Accounting', 27.0, 14.766666666666667],
#        [nan, 25.0, 14.766666666666667],
#        [nan, 22.0, 14.766666666666667],
#        [nan, 22.0, 14.766666666666667],
# ...

# %%
y
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, 14.766666666666667],
#        ['Customer Relations', 22.0, 14.766666666666667],
#        ['Accounting', 25.0, 14.766666666666667],
#        ['Accounting', 27.0, 14.766666666666667],
#        [nan, 25.0, 14.766666666666667],
#        [nan, 22.0, 14.766666666666667],
#        [nan, 22.0, 14.766666666666667],
# ...

# %%
y= dt.iloc[:,3:6].values

# %%
y
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, nan],
#        ['Customer Relations', 22.0, nan],
#        ['Accounting', 25.0, nan],
#        ['Accounting', 27.0, nan],
#        [nan, 25.0, nan],
#        [nan, 22.0, nan],
#        [nan, 22.0, nan],
#        [nan, 24.0, nan],
#        [nan, 27.0, nan],
#        [nan, 22.0, nan],
#        [nan, 33.0, 13.0],
#        [nan, 36.0, 7.0],
# ...

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values =  'NaN',strategy ='median',axis=0)
imputer= imputer.fit(y[:,1:3])
y[:,1:3]=imputer.transform(y[:,1:3])
# Out:
# C:\Users\Gadewar\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
y
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, 16.5],
#        ['Customer Relations', 22.0, 16.5],
#        ['Accounting', 25.0, 16.5],
#        ['Accounting', 27.0, 16.5],
#        [nan, 25.0, 16.5],
#        [nan, 22.0, 16.5],
#        [nan, 22.0, 16.5],
#        [nan, 24.0, 16.5],
#        [nan, 27.0, 16.5],
#        [nan, 22.0, 16.5],
#        [nan, 33.0, 13.0],
# ...

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy= 'most_frequent' )
x[:,0:1]=imp.fit_transform(x[:,0:1])

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, 14.766666666666667],
#        ['Customer Relations', 22.0, 14.766666666666667],
#        ['Accounting', 25.0, 14.766666666666667],
#        ['Accounting', 27.0, 14.766666666666667],
#        [nan, 25.0, 14.766666666666667],
#        [nan, 22.0, 14.766666666666667],
#        [nan, 22.0, 14.766666666666667],
# ...

# %%
from  sklearn.preprocessing import Imputer
imputer=Imputer(missing_values ='Nan',strategy='mean',axis=0)
imputer=imputer.fit(x[:,1:3])
x[:,1:3]=imputer.transform(x[:,1:3])
# Out:
# C:\Users\Gadewar\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-72e4e742ebdf> in <module>
#       1 from  sklearn.preprocessing import Imputer
#       2 imputer=Imputer(missing_values ='Nan',strategy='mean',axis=0)
# ----> 3 imputer=imputer.fit(x[:,1:3])
#       4 x[:,1:3]=imputer.transform(x[:,1:3])
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\imputation.py in fit(self, X, y)
#     167                                                    self.strategy,
#     168                                                    self.missing_values,
# ...

# %%
x= dt.iloc[:,3:6].values

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, nan],
#        ['Customer Relations', 22.0, nan],
#        ['Accounting', 25.0, nan],
#        ['Accounting', 27.0, nan],
#        [nan, 25.0, nan],
#        [nan, 22.0, nan],
#        [nan, 22.0, nan],
#        [nan, 24.0, nan],
#        [nan, 27.0, nan],
#        [nan, 22.0, nan],
#        [nan, 33.0, 13.0],
#        [nan, 36.0, 7.0],
# ...

# %%
from  sklearn.preprocessing import Imputer
imputer=Imputer(missing_values ='NaN',strategy='mean',axis=0)
imputer=imputer.fit(x[:,1:3])
x[:,1:3]=imputer.transform(x[:,1:3])
# Out:
# C:\Users\Gadewar\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, 14.766666666666667],
#        ['Customer Relations', 22.0, 14.766666666666667],
#        ['Accounting', 25.0, 14.766666666666667],
#        ['Accounting', 27.0, 14.766666666666667],
#        [nan, 25.0, 14.766666666666667],
#        [nan, 22.0, 14.766666666666667],
#        [nan, 22.0, 14.766666666666667],
# ...
